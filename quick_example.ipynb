# %%
import globals

# %%
detector_model = load_detector_model()
bottling_model = load_bottling_model()
model = load_model('20231024-best_weights_resnet50.hdf5', bottling_model)

# %%
path = 'quick_test/chihuahua.jpg'

# %%
detect_and_predict_breed(path, detector_model, bottling_model, model)
# Out:
# The predicted breed of dog in this image is Chihuahua
